# %% [markdown]
# # Yelp API - Lab
#
#
#
# ## Introduction
#
# Now that we've seen how the Yelp API works, it's time to put those API and SQL skills to work in order to do some basic business analysis! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
# * Create a DB on AWS to store information from Yelp about businesses
# * Create HTTP requests to get data from Yelp API
# * Parse HTTP responses and insert the information into your DB
# * Perform pagination to retrieve troves of data!
# * Write SQL queries to answer questions about your data

# %% [markdown]
# ## Problem Introduction
#
# For this lab you will analyze the yelp data for a group of businesses to learn more about an industry. You will choose a type of business (Italian Restuarants, Nail Salons, Crossfit gyms) and a location to analyze. Then you will get data from the Yelp API, store that data in a SQL Database on AWS, and write queries to answer questions about the data.
#
#
# ### Process:
#
# 1. Read through the SQL questions and the API documentation to determine which pieces of information you need to pull from the Yelp API.
#
# 2. Create a DB schema with 2 tables. One for the businesses and one for the reviews.
#
# 3. Create code to:
#   - Perform a search of businesses using pagination
#   - Parse the API response for specific data points
#   - Insert the data into your AWS DB
#
# 4. Use the functions above in a loop that will paginate over the results to retrieve all of the results.
#
# 5. Create functions to:
#   - Retrieve the reviews data of one business
#   - Parse the reviews response for specific review data
#   - Insert the review data into the DB
#
# 6. Using SQL, query all of the business IDs. Using the 3 Python functions you've created, run your business IDs through a loop to get the reviews for each business and insert them into your DB.
#
# 7. Write SQL queries to answer the following questions about your data.
#
#
# Bonus Steps:
# - Place your helper functions in a package so that your final notebook only has the major steps listed.
# - Rewrite your business search functions to be able take an argument for the type of business you are searching for.
# - Add another group of businesses to your database.

# %% [markdown]
#
# ## SQL Questions:
#
# - Which are the 5 most reviewed businesses?
# - What is the highest rating recieved in your data set and how many businesses have that rating?
# - What percentage of businesses have a rating greater than or  4.5?
# - What percentage of businesses have a rating less than 3?
# - What is the average rating of restaurants that have a price label of one dollar sign? Two dollar signs? Three dollar signs?
# - Return the text of the reviews for the most reviewed restaurant.
# - Return the name of the business with the most recent review.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the restaurant with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the restaurant with the least reviews.

# %% [markdown]
# ## Part 1 - Understanding your data and question
#
# Lok at the question and determine what data you will need to store in your database in order to answer the questions. Start to thin about your DB schema. What tables will you want to create and what columns will you ahve for those tables.
#
# Look at the API documentation, and determine what fields of the API response you will match up with the columns you want in your DB tables.
#
#
# https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# ## Part 2 - Set up the DB
#
# Now that you are familiar with the data, create your SQL queries to create the DB and the appropriate tables.

# %% [markdown]
# ### Foriegn Keys
#
# BFor this project you will have two tables that you need to link using a foreign key. Below is some information about how to create a foriegn key.
#
# http://www.mysqltutorial.org/mysql-foreign-key/

# %% [markdown]
# ### Using DB:
#
# For this lab, you can either store the data on one DB or put in on both of the partners DBs. If you decide to put it on one DB, you want to make sure both partners have access to it.  To do this you want to add a user to your DB.
#
# [how to add a new user](https://howchoo.com/g/mtm3zdq2nzv/how-to-add-a-mysql-user-and-grant-privileges)

# %%
import yelp_config
import mysql.connector
import requests
import json

# %%
# Establish connection to database

cnx = mysql.connector.connect(
    host = yelp_config.host,
    user = yelp_config.user,
    passwd = yelp_config.passwd,
    db='yelp')

# create cursor object
c = cnx.cursor()

# %%
# Create a table for the Businesses
#done in SQL

# %%
# Create a table for the reviews
#done in SQL

# %% [markdown]
# ## Part 3 - Create ETL pipeline for the business data from the API
#
# Now that you know what data you need from the API, you want to write code that will execute a api call, parse those results and then insert the results into the DB.
#
# It is helpful to break this up into three different functions (*api call, parse results, and insert into DB*) and then you can write a function/script that pull the other three functions together.
#
# Let's first do this for the Business endpoint.

# %%
 #Authorization info - RZ

# Client ID - 'd31wiC8swpcod_WEbvT7ew'

api_key = 'Fi9YM7w1buyiE4HRcOjM6ocNL09YAUnALRfrk6TDVAlJfMu1GQW0Dr_H79RRoSDP0T659WFccMzlNVWgq1qqL3w93NaG_ebGuW3gKsRek99el_RkrXl-wxBG9jbpXXYx'

# %%
count = 0

# %%
#insert API url
url = 'https://api.yelp.com/v3/businesses/search'

# what type of business do you want to search
term = 'Cocktail Bars'

#where do you want to perform this search
location = "7604 3rd Ave Brooklyn NY, 11209"

# what is your other parameter you want to search against

#update: headers are providing the api Authorization as required by source site.

headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

url_params = {  'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                 'limit' : 50,
                'offset': count }

# %%
# Write a function to make a call to the yelp business API

def yelp_call(url, headers, params):
    response = requests.get(url, headers = headers, params =url_params)
    business = json.loads(response.text)
    return business['businesses']

# %%
yelp_call(url, headers, url_params)
# Out:
# [{'id': 'zFt9LNoKaVVc3kOWHEaVgw',
#   'alias': 'matter-brooklyn-2',
#   'name': 'MATTER',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gnInyae4cbPmCsjmGud7xg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/matter-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 96,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6306310365234,
#    'longitude': -74.0282921165967},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7604 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7604 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17186503030',
#   'display_phone': '(718) 650-3030',
#   'distance': 13.653043650813258},
#  {'id': '2o3xF6DnHDfZ3k1mPioh4A',
#   'alias': 'townhouse-275-brooklyn',
#   'name': 'Townhouse 275',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VBFjnu6ngEeA0bJ6rGh28A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/townhouse-275-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 62,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6182556, 'longitude': -74.033989},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '275 94th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['275 94th St', 'Brooklyn, NY 11209']},
#   'phone': '+13475604001',
#   'display_phone': '(347) 560-4001',
#   'distance': 1449.6947436233193},
#  {'id': 'FXD22Sgwg1bbeNk-kuYeig',
#   'alias': 'catch-22-bay-ridge',
#   'name': 'Catch 22',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PPcCAvtcYfaXpvTxitpuVQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/catch-22-bay-ridge?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 24,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.6328738358923,
#    'longitude': -74.0270650028197},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7221 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bay Ridge',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7221 3rd Ave', 'Bay Ridge, NY 11209']},
#   'phone': '+17189215869',
#   'display_phone': '(718) 921-5869',
#   'distance': 275.93711572559533},
#  {'id': 'nZ0Y8ngCxpY3xlz4f4pNTQ',
#   'alias': 'brooklyn-beet-company-brooklyn',
#   'name': 'Brooklyn Beet Company',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gfXAEcfRRGb41ngrmug9Hw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brooklyn-beet-company-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 423,
#   'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6333416, 'longitude': -74.0268741},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7205 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7205 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+13474920020',
#   'display_phone': '(347) 492-0020',
#   'distance': 329.95297123865316},
#  {'id': 'AbDiDY7kYDSldaKbGpoSlg',
#   'alias': 'the-brooklyn-firefly-brooklyn',
#   'name': 'The Brooklyn Firefly',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4bTWP3GhL1kjuhlsduC71w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-brooklyn-firefly-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 216,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.63468, 'longitude': -74.02631},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7003 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7003 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17188335000',
#   'display_phone': '(718) 833-5000',
#   'distance': 483.0800697087796},
#  {'id': 'uuHujhrkVQdS8XVSGWW2mA',
#   'alias': 'cebu-bar-and-bistro-brooklyn-2',
#   'name': 'Cebu Bar & Bistro',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DzJIyK2yJq1X_Zi2yVFT0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cebu-bar-and-bistro-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 678,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.62186, 'longitude': -74.031383},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '8801 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8801 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17184925095',
#   'display_phone': '(718) 492-5095',
#   'distance': 1005.7241661207371},
#  {'id': 'VP_HZr_j0dXKd80lUBfsyg',
#   'alias': 'the-wicked-monk-brooklyn-3',
#   'name': 'The Wicked Monk',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TtzkeiyHmSE2yU7YOMhAHg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-wicked-monk-brooklyn-3?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 230,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.616988, 'longitude': -74.034023},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '9510 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9510 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+13474975152',
#   'display_phone': '(347) 497-5152',
#   'distance': 1587.7747160172821},
#  {'id': 'Xiqf_VUWZeoAo7c2kfEiXw',
#   'alias': 'delias-lounge-and-restaurant-brooklyn',
#   'name': "Delia's Lounge & Restaurant",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/anCaemPBjgqbMQsG0IzUrQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/delias-lounge-and-restaurant-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 157,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.618809, 'longitude': -74.033272},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '9224 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9224 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17187457999',
#   'display_phone': '(718) 745-7999',
#   'distance': 1375.6001551797883},
#  {'id': 'PY-v9ObQWyS1Oiz89IUfEw',
#   'alias': 'skinflints-brooklyn',
#   'name': 'Skinflints',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1lALGHjZibXR1JMj4EgnkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/skinflints-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 305,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.626544, 'longitude': -74.024139},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7902 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7902 5th Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17187451116',
#   'display_phone': '(718) 745-1116',
#   'distance': 585.8977149706476},
#  {'id': 'HzJBBKuBGWdRHMfNW0Ve0w',
#   'alias': 'three-jolly-pigeons-brooklyn-2',
#   'name': 'Three Jolly Pigeons',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LhISkl1Fxc2IC6b6zy6TeQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/three-jolly-pigeons-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 65,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.636625, 'longitude': -74.025931},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '6802 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11226',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6802 3rd Ave', 'Brooklyn, NY 11226']},
#   'phone': '+17187459350',
#   'display_phone': '(718) 745-9350',
#   'distance': 700.0752489188193},
#  {'id': 'v3O_QyIVp5ZthiFgBzoEOA',
#   'alias': 'l-wren-brooklyn',
#   'name': "L'Wren",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2UWrF5tr0-cLWqsFjrk5Bg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-wren-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 32,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.65065, 'longitude': -74.00476},
#   'transactions': [],
#   'location': {'address1': '4004 5th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4004 5th Ave', 'Brooklyn, NY 11232']},
#   'phone': '+19179091894',
#   'display_phone': '(917) 909-1894',
#   'distance': 2992.1093372131368},
#  {'id': 'MKMx5TAmzXfjgLdXgu6FVQ',
#   'alias': 'south-brooklyn-foundry-brooklyn',
#   'name': 'South Brooklyn Foundry',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/urBF0_-UT_nPT6yMo6b12g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/south-brooklyn-foundry-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 251,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.63539, 'longitude': -74.02602},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6909 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6909 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17183335287',
#   'display_phone': '(718) 333-5287',
#   'distance': 566.9121251103512},
#  {'id': '2MfnOT7FxGddy0dydHTrGA',
#   'alias': 'young-ethels-brooklyn',
#   'name': "Young Ethel's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o9ywdG2JetjyNCBgC_MjCQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/young-ethels-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 15,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.66716, 'longitude': -73.98817},
#   'transactions': [],
#   'location': {'address1': '506 5th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['506 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+19293676469',
#   'display_phone': '(929) 367-6469',
#   'distance': 5295.650060266246},
#  {'id': 'az4tZj2pFMBCy-X84cQXxA',
#   'alias': 'windy-city-ale-house-brooklyn',
#   'name': 'Windy City Ale House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/c9BMj2XKcEu7FgyumEtTww/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/windy-city-ale-house-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 121,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.628039, 'longitude': -74.028829},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7915 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7915 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17186305700',
#   'display_phone': '(718) 630-5700',
#   'distance': 289.53340791076545},
#  {'id': 'mY_dEQM9poopjV0y4Hvnww',
#   'alias': 'coszcal-de-allende-brooklyn',
#   'name': 'Coszcal De Allende',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9kgvFultFzATpuOLC14tjw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/coszcal-de-allende-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 127,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.63617, 'longitude': -74.0262},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6824 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11220',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6824 3rd Ave', 'Brooklyn, NY 11220']},
#   'phone': '+17189213523',
#   'display_phone': '(718) 921-3523',
#   'distance': 645.8987484527207},
#  {'id': '_5dovFoqS-xKkjSUTcIDVg',
#   'alias': 'quarter-brooklyn',
#   'name': 'Quarter',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lP0tx9fsMAkxyM_SU5kmxQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/quarter-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 87,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6618799, 'longitude': -73.99314},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '676 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['676 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+17187880989',
#   'display_phone': '(718) 788-0989',
#   'distance': 4577.826602965697},
#  {'id': 'L3HDotnnzGKZfoy62kZAkg',
#   'alias': 'camperdown-elm-brooklyn',
#   'name': 'Camperdown Elm',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XpUufZ0CjbzNNpW807mRkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/camperdown-elm-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 111,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.66312, 'longitude': -73.98454},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '441 7th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['441 7th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+13472944786',
#   'display_phone': '(347) 294-4786',
#   'distance': 5180.347002100405},
#  {'id': 'g3FOPlO-Gp0J4HfjurW74Q',
#   'alias': 'gourmet-kitchen-brooklyn-3',
#   'name': 'Gourmet Kitchen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/53GXue3IE-P8LYGR_LJkcA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gourmet-kitchen-brooklyn-3?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 162,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.63581, 'longitude': -74.02567},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6819 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11220',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6819 3rd Ave', 'Brooklyn, NY 11220']},
#   'phone': '+13476626821',
#   'display_phone': '(347) 662-6821',
#   'distance': 622.6115305814905},
#  {'id': '_-89MKTICre2Gj6Mq-qhDA',
#   'alias': 'commonwealth-brooklyn',
#   'name': 'Commonwealth',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m7_BatTOBC7qM3OaWXD3KA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/commonwealth-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 169,
#   'categories': [{'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.667167, 'longitude': -73.987648},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '497 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['497 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+17187682040',
#   'display_phone': '(718) 768-2040',
#   'distance': 5323.473384036135},
#  {'id': 'l_jZX0IQqHzCwC_7KcKS7A',
#   'alias': 'the-owl-farm-brooklyn',
#   'name': 'The Owl Farm',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_IGs_qjVqn2L2vQLbZ0lnw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-owl-farm-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 194,
#   'categories': [{'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.669616, 'longitude': -73.986601},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '297 9th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['297 9th St', 'Brooklyn, NY 11215']},
#   'phone': '+17184994988',
#   'display_phone': '(718) 499-4988',
#   'distance': 5588.049106685814},
#  {'id': '4CheGhBNFK8KBbsVEhYJKA',
#   'alias': 'south-brooklyn',
#   'name': 'South',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AqoQeGSpno8EUCywlfmwAA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/south-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 156,
#   'categories': [{'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.66313, 'longitude': -73.99117},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '629 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['629 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+17188324720',
#   'display_phone': '(718) 832-4720',
#   'distance': 4790.243788458985},
#  {'id': 'qh8zROULNPGh23ZoFVZAZg',
#   'alias': 'pour-house-of-bay-ridge-brooklyn-2',
#   'name': 'Pour House of Bay Ridge',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GY14HDBR7Ejx_Ikq2Rvwmg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pour-house-of-bay-ridge-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 39,
#   'categories': [{'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.628376, 'longitude': -74.028717},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7901 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7901 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17184916658',
#   'display_phone': '(718) 491-6658',
#   'distance': 250.97084552913802},
#  {'id': 'U3d5QB5a8Q37Csj7L1aBXA',
#   'alias': 'mama-tried-brooklyn-2',
#   'name': 'Mama Tried',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6uSqwc2X5ZxHpIqEuCk0ZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mama-tried-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 26,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.66046, 'longitude': -74.00082},
#   'transactions': [],
#   'location': {'address1': '147 27th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['147 27th St', 'Brooklyn, NY 11232']},
#   'phone': '+19293878181',
#   'display_phone': '(929) 387-8181',
#   'distance': 4067.915341868228},
#  {'id': 'Y6FMtiM2Q3CwcuxI0E4USQ',
#   'alias': 'blue-agave-brooklyn-2',
#   'name': 'Blue Agave',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b_ojZISZgaouziMGXeH17A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-agave-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 228,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6330902, 'longitude': -74.0268565},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7215-B 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7215-B 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17184390808',
#   'display_phone': '(718) 439-0808',
#   'distance': 305.24422505481016},
#  {'id': 'HhXM_ZKngz5oY6Hhjo8MqA',
#   'alias': 'freddys-bar-brooklyn-2',
#   'name': "Freddy's Bar",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vCyPRc8hPNT2JXigMyNHmw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/freddys-bar-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 216,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'musicvenues', 'title': 'Music Venues'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.6631969, 'longitude': -73.991061},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '627 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['627 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+17187680131',
#   'display_phone': '(718) 768-0131',
#   'distance': 4802.943824597114},
#  {'id': 'xvqG8x-EMcUysuOzY7RsPg',
#   'alias': 'glow-thai-brooklyn',
#   'name': 'Glow Thai',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xDSnxQS7WgiGaHzBOje43A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/glow-thai-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 256,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.63394, 'longitude': -74.02661},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7107 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7107 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17187481920',
#   'display_phone': '(718) 748-1920',
#   'distance': 399.71807645879363},
#  {'id': 'YjD9sNbooHMHpvjDzc89rA',
#   'alias': 'zona-sur-bar-bistro-brooklyn',
#   'name': 'Zona Sur Bar Bistro',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bLB58XyjpEzrVMC5r3g_6Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zona-sur-bar-bistro-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 323,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.650275, 'longitude': -74.009116},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4314 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4314 4th Ave', 'Brooklyn, NY 11232']},
#   'phone': '+17187881606',
#   'display_phone': '(718) 788-1606',
#   'distance': 2725.000165578141},
#  {'id': 't-UTPqMlFI36XIvNPBVdEQ',
#   'alias': 'baci-ristorante-brooklyn',
#   'name': 'Baci Ristorante',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZVj-IyNUJ51kHN2Q4PuMkA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/baci-ristorante-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 56,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.62452, 'longitude': -74.03091},
#   'transactions': [],
#   'location': {'address1': '8424 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8424 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17183335879',
#   'display_phone': '(718) 333-5879',
#   'distance': 711.7710186743386},
#  {'id': '5f3M0k7mTjrKoQFJW-PFzg',
#   'alias': 'lock-yard-brooklyn',
#   'name': 'Lock Yard',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/X4FIkoR7HmPnq7b4_ki42Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lock-yard-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 297,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'hotdog', 'title': 'Hot Dogs'},
#    {'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.617264, 'longitude': -74.029419},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '9221 5th Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9221 5th Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17183335282',
#   'display_phone': '(718) 333-5282',
#   'distance': 1481.1228979301065},
#  {'id': 'ZtCD7e_LlW-pwEUY6bvusQ',
#   'alias': 'irish-haven-brooklyn',
#   'name': 'Irish Haven',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fXCRrRpbJ2Iqz5-QuiHNKQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/irish-haven-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 77,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'irish_pubs', 'title': 'Irish Pub'},
#    {'alias': 'divebars', 'title': 'Dive Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.641891, 'longitude': -74.016845},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '5721 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11220',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['5721 4th Ave', 'Brooklyn, NY 11220']},
#   'phone': '+17184399893',
#   'display_phone': '(718) 439-9893',
#   'distance': 1589.791167821833},
#  {'id': 'HmdGSeQbK2vI3Vp7xfcIrg',
#   'alias': 'catrinas-mexican-grill-brooklyn',
#   'name': 'Catrinas Mexican Grill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ORWCjcpo5hFpLFJsgwIeIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/catrinas-mexican-grill-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 106,
#   'categories': [{'alias': 'tex-mex', 'title': 'Tex-Mex'},
#    {'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.63248, 'longitude': -74.02767},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7316 3rd Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7316 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17188334400',
#   'display_phone': '(718) 833-4400',
#   'distance': 217.42326721215161},
#  {'id': '_M5FVY4hkcuU-ASdVZPfRQ',
#   'alias': 'tacos-el-bronco-brooklyn-2',
#   'name': 'Tacos El Bronco',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b9buJfJeMA0ETspHhAqzUg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-el-bronco-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 558,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.65006, 'longitude': -74.00915},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '4324 4th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11220',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['4324 4th Ave', 'Brooklyn, NY 11220']},
#   'phone': '+17187882229',
#   'display_phone': '(718) 788-2229',
#   'distance': 2702.647544440579},
#  {'id': 'rbcTKkA_sn4FG7Oo8vrIWA',
#   'alias': 'lowlands-bar-brooklyn',
#   'name': 'Lowlands Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WXRNgBnhcmR5u7MTL4sjGA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lowlands-bar-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 70,
#   'categories': [{'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6684722900391,
#    'longitude': -73.9931716918945},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '543 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['543 3rd Ave', 'Brooklyn, NY 11215']},
#   'phone': '+13474639458',
#   'display_phone': '(347) 463-9458',
#   'distance': 5153.92595346037},
#  {'id': 'gY6aPkUcyltomwF6FrR9gw',
#   'alias': 'barbès-brooklyn-2',
#   'name': 'Barbès',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UoGCwzZYu9WNqAEyxTGCrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barb%C3%A8s-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 170,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.667724609375, 'longitude': -73.9839019775391},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '376 9th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['376 9th St', 'Brooklyn, NY 11215']},
#   'phone': '+13474220248',
#   'display_phone': '(347) 422-0248',
#   'distance': 5584.991175563022},
#  {'id': 'GimProZnHbVWu8MbV__s4w',
#   'alias': 'skylark-bar-brooklyn',
#   'name': 'Skylark Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/C5WOZ2XyPPGMdLsLE-vxSQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/skylark-bar-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 99,
#   'categories': [{'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.667759, 'longitude': -73.987106},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '477 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['477 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+13472278196',
#   'display_phone': '(347) 227-8196',
#   'distance': 5404.935307928956},
#  {'id': 'su27bl6tqjh2ucbMc1FuvA',
#   'alias': 'lamoza-brooklyn-2',
#   'name': 'Lamoza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BYWqEGr3DWIwMrq3XKfaaA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lamoza-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 90,
#   'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#    {'alias': 'hookah_bars', 'title': 'Hookah Bars'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.62992, 'longitude': -74.028718},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7704 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7704 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17182383625',
#   'display_phone': '(718) 238-3625',
#   'distance': 81.73471710707372},
#  {'id': 'QS7LomUJFfx9LufSx4RVvQ',
#   'alias': 'sea-witch-brooklyn-2',
#   'name': 'Sea Witch',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Puak6yp2V1BKhURkHeEP5Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sea-witch-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 274,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.66082, 'longitude': -73.993538},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '703 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['703 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+13472277166',
#   'display_phone': '(347) 227-7166',
#   'distance': 4466.451903721741},
#  {'id': 'v4cXt2qe9pq_XWJflL5ISg',
#   'alias': 'parc-oasis-oyster-bar-brooklyn',
#   'name': 'Parc Oasis Oyster Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pm4NyGBDUgjV965Kkk8Rbg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/parc-oasis-oyster-bar-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 143,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6290427824765, 'longitude': -74.005197991996},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6403 11th Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11219',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['6403 11th Ave', 'Brooklyn, NY 11219']},
#   'phone': '+19292922010',
#   'display_phone': '(929) 292-2010',
#   'distance': 1970.4365907459348},
#  {'id': 'bEadv-XnsYa5IaBD_VcHfA',
#   'alias': 'salty-dog-bar-and-restaurant-brooklyn',
#   'name': 'Salty Dog Bar and Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/79NXIIXN5ecI5avjv_f8RQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/salty-dog-bar-and-restaurant-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 251,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.631083, 'longitude': -74.027611},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7509 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7509 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17182380030',
#   'display_phone': '(718) 238-0030',
#   'distance': 84.62867727150973},
#  {'id': 'Zwrf1_mSetFmO-Z49bRDbA',
#   'alias': 'filament-at-the-landing-brooklyn',
#   'name': 'Filament at the Landing',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_Fx4fHL6jZRuMK6tGAUg_A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/filament-at-the-landing-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 24,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.656632, 'longitude': -74.00862},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '220 36th St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['220 36th St', 'Brooklyn, NY 11232']},
#   'phone': '+13474178494',
#   'display_phone': '(347) 417-8494',
#   'distance': 3340.906019491565},
#  {'id': '0O0DV4tKQkp2lS2wGcg_7A',
#   'alias': 'bin-5-staten-island',
#   'name': 'Bin 5',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NsezwQxQ3riqPU9IqvXlrA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bin-5-staten-island?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 344,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.613335, 'longitude': -74.065258},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '1233 Bay St',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10305',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1233 Bay St', 'Staten Island, NY 10305']},
#   'phone': '+17184487275',
#   'display_phone': '(718) 448-7275',
#   'distance': 3653.2092192800114},
#  {'id': '46gT-bvsj5sXDMLAAcybzQ',
#   'alias': 'barrows-intense-tasting-room-brooklyn',
#   'name': "Barrow's Intense Tasting Room",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/J9QOalzPrO8DJlugCOoRoA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barrows-intense-tasting-room-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 18,
#   'categories': [{'alias': 'distilleries', 'title': 'Distilleries'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.65689, 'longitude': -74.00586},
#   'transactions': [],
#   'location': {'address1': '86 34th Street C134',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['86 34th Street C134', 'Brooklyn, NY 11232']},
#   'phone': '+19175971084',
#   'display_phone': '(917) 597-1084',
#   'distance': 3480.148751939458},
#  {'id': '76B7-T4f1EdsQsoI0NM9Wg',
#   'alias': 'beso-staten-island',
#   'name': 'Beso',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h58cLBZNiQF0gss7OSTC-Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/beso-staten-island?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 506,
#   'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#    {'alias': 'tapas', 'title': 'Tapas Bars'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6433825472408,
#    'longitude': -74.0769100798997},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '11 Schuyler St',
#    'address2': '',
#    'address3': '',
#    'city': 'Staten Island',
#    'zip_code': '10301',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['11 Schuyler St', 'Staten Island, NY 10301']},
#   'phone': '+17188168162',
#   'display_phone': '(718) 816-8162',
#   'distance': 4327.7635608806395},
#  {'id': '8u9HZbzpry_cg8-8FBEKvA',
#   'alias': 'bay-ridge-manor-brooklyn',
#   'name': 'Bay Ridge Manor',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QO3bRX-RN9-U8KvWqBjqCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bay-ridge-manor-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 54,
#   'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.628761, 'longitude': -74.023527},
#   'transactions': [],
#   'location': {'address1': '476 76th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['476 76th St', 'Brooklyn, NY 11209']},
#   'phone': '+17187488855',
#   'display_phone': '(718) 748-8855',
#   'distance': 464.6816494405514},
#  {'id': 'X4YuMX1KgFxIc3pNkRDBZA',
#   'alias': 'the-kettle-black-brooklyn-2',
#   'name': 'The Kettle Black',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EDt9-7XLGzWVkSl2G6mCLQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-kettle-black-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 371,
#   'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.6229, 'longitude': -74.03159},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '8622 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8622 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17186807862',
#   'display_phone': '(718) 680-7862',
#   'distance': 899.4414461728927},
#  {'id': '__8z_m88GNHbkvJAgUYWBw',
#   'alias': 'red-oak-brooklyn-2',
#   'name': 'Red Oak',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BDCko-vSNar-8l0e6ozZjg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/red-oak-brooklyn-2?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 152,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'hookah_bars', 'title': 'Hookah Bars'},
#    {'alias': 'lounges', 'title': 'Lounges'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.625395, 'longitude': -74.029946},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '8305 3rd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['8305 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17186800800',
#   'display_phone': '(718) 680-0800',
#   'distance': 595.2683365286088},
#  {'id': '2ClkHmHOG_m5EuHTt-l_Ig',
#   'alias': 'buttermilk-bar-brooklyn',
#   'name': 'Buttermilk Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T3bCqlaotq8WQkzLpoHQEA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/buttermilk-bar-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 111,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.66476, 'longitude': -73.989658},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '577 5th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['577 5th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+17187886297',
#   'display_phone': '(718) 788-6297',
#   'distance': 5010.752000507955},
#  {'id': 'uBxSYU7JMsqI_9iMP0kl2Q',
#   'alias': 'the-common-brooklyn-3',
#   'name': 'The Common',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sQI6f08Z3etVzEo5WBuc6g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-common-brooklyn-3?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 110,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.61782, 'longitude': -74.03353},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '9406 3rd Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11209',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9406 3rd Ave', 'Brooklyn, NY 11209']},
#   'phone': '+17186803030',
#   'display_phone': '(718) 680-3030',
#   'distance': 1486.319335999067},
#  {'id': '-RRauorKocNhH2n74rkfnQ',
#   'alias': 'frying-pan-brooklyn-brooklyn',
#   'name': 'Frying Pan Brooklyn',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/36DH837ETsMjMVPV7NCGpw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/frying-pan-brooklyn-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 22,
#   'categories': [{'alias': 'eatertainment', 'title': 'Eatertainment'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6569784, 'longitude': -74.0071251},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '51 35th St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11232',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['51 35th St', 'Brooklyn, NY 11232']},
#   'phone': '+16467081814',
#   'display_phone': '(646) 708-1814',
#   'distance': 3450.392480523063},
#  {'id': 'KWIPsr4kQBLIpPTSwKTlig',
#   'alias': 'brookvin-brooklyn',
#   'name': 'Brookvin',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/77lX0NnkwhN6rjfFjx0PLA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brookvin-brooklyn?adjust_creative=d31wiC8swpcod_WEbvT7ew&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=d31wiC8swpcod_WEbvT7ew',
#   'review_count': 289,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'tapas', 'title': 'Tapas Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6652526855469,
#    'longitude': -73.9825668334961},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '381 7th Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11215',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['381 7th Ave', 'Brooklyn, NY 11215']},
#   'phone': '+17187689463',
#   'display_phone': '(718) 768-9463',
#   'distance': 5459.7982431760975}]

# %%
#request api and convert to json
response = yelp_call(url, headers, url_params)
business = json.loads(response.text)
#identify total number returned in request
business['total']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-e1718cf555ee> in <module>
#       1 #request api and convert to json
#       2 response = yelp_call(url, headers, url_params)
# ----> 3 business = json.loads(response.text)
#       4 #identify total number returned in request
#       5 business['total']
#
# AttributeError: 'list' object has no attribute 'text'

# %%
#preview the data to determine what keys need to be parsed
business['businesses'][:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-58df14c446b7> in <module>
#       1 #preview the data to determine what keys need to be parsed
# ----> 2 business['businesses'][:5]
#
# NameError: name 'business' is not defined

# %%
# write a function to parse the API response 
def parse_results(stuff):
   
    parsed_business = []
    for items in stuff:
        try:
            parsed_tuple = (items['id'], items['name'],' '.join(items['location']['display_address']), items['rating'],
                        items['review_count'], len(items['price']))
            parsed_business.append(parsed_tuple)
        except: 
            parsed_tuple = (items['id'], items['name'],' '.join(items['location']['display_address']), items['rating']
                        ,items['review_count'], 0)
            parsed_business.append(parsed_tuple)
    return parsed_business
    

# so that you can easily insert the data in to the DB

# %%
# Write a function to take your parsed data and insert it into the DB

def db_insert(cnx, c, parsed_results):
    # your code to insert and commit the results
    c.executemany("""INSERT INTO yelp.cocktail_bars (business_id, name, location, rating, review_count, price)
               VALUES(%s, %s, %s, %s, %s, %s)""", parsed_results)
    cnx.commit()

# %%
count = 0

# %%
#business pagination
#dumping businesses into yelp.cocktail_bars Table
count = 0
while count < 228:
    url_params['offset'] = count
    results = yelp_call(url, headers, url_params)
    parsed_results = parse_results(results)
    db_insert(cnx, c, parsed_results)
    count += 50
    if count > 228:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3208235605c2> in <module>
#       5     url_params['offset'] = count
#       6     results = yelp_call(url, headers, url_params)
# ----> 7     parsed_results = parse_results(results)
#       8     db_insert(cnx, c, parsed_results)
#       9     count += 50
#
# NameError: name 'parse_results' is not defined

# %% [markdown]
# ## Part 4 -  Create ETL pipeline for the restaurant review data from the API
#
# You've done this for the Businesses, now you need to do this for reviews. You will follow the same process, but your functions will be specific to reviews.

# %%
#Grabs each unique business id and stores them in the "reviews_url" var

def business_get_url(data):
    business_id = []
    for i in data:
        business_id.append(i['id'])
    review_url = []
    for i in business_id:
        review_url.append(f'https://api.yelp.com/v3/businesses/{i}/reviews' )  
    return review_url
    
 # takes business['businesses'] at data input

# %%
business_review_urls = business_get_url(business['businesses'])
#inspecting url return
business_review_urls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3e6c99c7144d> in <module>
# ----> 1 business_review_urls = business_get_url(business['businesses'])
#       2 #inspecting url return
#       3 business_review_urls
#
# NameError: name 'business' is not defined

# %%
#api call for review data  // needs revision
def review_call(review_urls, headers):
    for urls in review_urls:
        response = requests.get(urls, headers = headers)
        review_data = json.loads(response.text)
    return review_data

# %%
review_response = review_call(business_review_urls, headers)
review_response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-8b5336eff22b> in <module>
# ----> 1 review_response = review_call(business_review_urls, headers)
#       2 review_response
#
# NameError: name 'business_review_urls' is not defined

# %%
review_response['reviews']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3276451fcd80> in <module>
# ----> 1 review_response['reviews']
#
# NameError: name 'review_response' is not defined

# %%
def review_parse(review_data):
    parse_list = []
    for i in review_data:
        parse_tuple = (i['id'], i['time_created'], i['text'])
        parse_list.append(parse_tuple)
    return parse_list

# %%
review_parse(review_response['reviews'])
# Out:
# [('ygCEo1hdcbZAkcPKuufkVA',
#   '2019-08-03 12:03:12',
#   'Sam is the man!\n\nLove my neighborhood and this place is my go to for great beer and great hangs. Delivery food friendly plus the best staff in the Sunset!'),
#  ('GZv1IGOkM_Xc5Y_sKkZsKw',
#   '2019-12-05 08:06:44',
#   "A bit sad that Parkette has gone away, but excited that Judy's has opened up in the neighborhood. I'm usually wary of gentrifiers/hipsters moving in as a..."),
#  ('5ei4Rd3g_f1NXbaGJTl18g',
#   '2019-06-11 19:54:50',
#   "As a neighborhood joint, you couldn't ask for more. Excellent coffee for weekday mornings, constantly rotating legit beer/wine selection for late nights,...")]

# %%
def review_db_insert(cnx, c, parsed_reviews):

# %%
one_review = review_call('https://api.yelp.com/v3/businesses/zFt9LNoKaVVc3kOWHEaVgw/reviews', headers)
new_obj = json.loads(one_review.text)
new_objf

# %%
# Write a function to parse out the relevant information from the reviews

# %%
# write a function to insert the parsed data into the reviews table

# %%
# combine the functions above into a single script

# %% [markdown]
# ## Part 5 -  Write SQL queries that will answer the questions posed.
#
# Now that your data is in the DB, you can answer the questions. Write SQL querires that will answer the questions. **Do not use Pandas in this lab**

# %%
# create connection

# %%
# execute SQL queries

# %% [markdown]
# # Extra Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < num and cur < 1000: #set num to total num of results
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    db_insert(parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 50
