# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#Load our dataframe account for the index columns
df = pd.read_csv('case_study.csv', index_col=0)
df
# Out:
#         _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938      9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939      9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940      9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941      9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942      9.0     5.0  7182017       7    18   2017    1200.0  2017000005
# ...        ...     ...      ...     ...   ...    ...       ...         ...
# 303774    36.0     5.0  5152017       5    15   2017    1200.0  2017012245
# 303775    36.0     6.0  6252017       6    25   2017    1200.0  2017012246
# 303776    36.0     7.0  7212017       7    21   2017    1200.0  2017012247
# 303777    36.0     7.0  7202017       7    20   2017    1200.0  2017012248
# 303778    36.0     7.0  7252017       7    25   2017    1200.0  2017012249
#
# ...

# %%
# Quickly check to see the size of our DF, both rows and columns
df.shape
# Out:
# (34545, 358)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34545 entries, 49938 to 303778
# Columns: 358 entries, _STATE to _AIDTST3
# dtypes: float64(352), int64(5), object(1)
# memory usage: 94.6+ MB

# %%
df.head()
# Out:
#        _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938     9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939     9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940     9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941     9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942     9.0     5.0  7182017       7    18   2017    1200.0  2017000005
#
#                _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  _PAREC1  \
# 49938  2.017000e+09       NaN  ...       2.0       2.0       2.0      4.0
# 49939  2.017000e+09       NaN  ...       1.0       1.0       1.0      1.0
# 49940  2.017000e+09       NaN  ...       3.0       2.0       1.0      3.0
# 49941  2.017000e+09       NaN  ...       2.0       2.0       2.0      2.0
# 49942  2.017000e+09       NaN  ...       2.0       2.0       1.0      1.0
#
#        _PASTAE1  _RFSEAT2  _RFSEAT3  _FLSHOT6  _PNEUMO2  _AIDTST3
# ...

# %%
df.describe()
# Out:
#              _STATE        FMONTH         IDATE        IMONTH          IDAY  \
# count  34545.000000  34545.000000  3.454500e+04  34545.000000  34545.000000
# mean      27.046693      6.966855  7.273633e+06      7.119323     15.229295
# std       12.026461      3.479398  3.476456e+06      3.476148      8.821280
# min        9.000000      1.000000  1.012018e+06      1.000000      1.000000
# 25%        9.000000      4.000000  4.192017e+06      4.000000      7.000000
# 50%       34.000000      7.000000  8.022017e+06      8.000000     15.000000
# 75%       36.000000     10.000000  1.021202e+07     10.000000     22.000000
# max       36.000000     12.000000  1.231202e+07     12.000000     31.000000
#
#               IYEAR      DISPCODE         SEQNO          _PSU  CTELENM1  ...  \
# count  34545.000000  34545.000000  3.454500e+04  3.454500e+04   18502.0  ...
# mean    2017.001274   1118.428137  2.017006e+09  2.017006e+09       1.0  ...
# ...

# %% [markdown]
# ## Subset your dataframe to only include the states in the tri-state area (NJ, CT, NY)

# %%
# your code here subset of states:  Conn, NJ, NY:  9, 34, 36

# Unnecessary; the case study indicates that the given set only inlcuded those three states.

# df[(df["_STATE"].isin(9, 34, 36))]

df[
    df["_STATE"].isin
    (
    [9, 34, 36]
    )
]
# Out:
#         _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938      9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939      9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940      9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941      9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942      9.0     5.0  7182017       7    18   2017    1200.0  2017000005
# ...        ...     ...      ...     ...   ...    ...       ...         ...
# 303774    36.0     5.0  5152017       5    15   2017    1200.0  2017012245
# 303775    36.0     6.0  6252017       6    25   2017    1200.0  2017012246
# 303776    36.0     7.0  7212017       7    21   2017    1200.0  2017012247
# 303777    36.0     7.0  7202017       7    20   2017    1200.0  2017012248
# 303778    36.0     7.0  7252017       7    25   2017    1200.0  2017012249
#
# ...

# %% [markdown]
# Now check to see how large our subset df.

# %%
# your code here
df.shape
# Out:
# (34545, 358)

# %%
df.describe()
# Out:
#              _STATE        FMONTH         IDATE        IMONTH          IDAY  \
# count  34545.000000  34545.000000  3.454500e+04  34545.000000  34545.000000
# mean      27.046693      6.966855  7.273633e+06      7.119323     15.229295
# std       12.026461      3.479398  3.476456e+06      3.476148      8.821280
# min        9.000000      1.000000  1.012018e+06      1.000000      1.000000
# 25%        9.000000      4.000000  4.192017e+06      4.000000      7.000000
# 50%       34.000000      7.000000  8.022017e+06      8.000000     15.000000
# 75%       36.000000     10.000000  1.021202e+07     10.000000     22.000000
# max       36.000000     12.000000  1.231202e+07     12.000000     31.000000
#
#               IYEAR      DISPCODE         SEQNO          _PSU  CTELENM1  ...  \
# count  34545.000000  34545.000000  3.454500e+04  3.454500e+04   18502.0  ...
# mean    2017.001274   1118.428137  2.017006e+09  2.017006e+09       1.0  ...
# ...

# %%
df["_STATE"].value_counts()
# Out:
# 36.0    12249
# 34.0    11708
# 9.0     10588
# Name: _STATE, dtype: int64

# %% [markdown]
# **PHYSHLTH** is the column we are interested in for this analysis, so let's start to investigate the column. Since we have a data cookbook, a.k.a. data dictionary) we want to start there before looking at the code.

# %%
df["PHYSHLTH"]
# Out:
# 49938     88.0
# 49939     88.0
# 49940      2.0
# 49941     88.0
# 49942     88.0
#           ...
# 303774    88.0
# 303775    88.0
# 303776     6.0
# 303777    88.0
# 303778    88.0
# Name: PHYSHLTH, Length: 34545, dtype: float64

# %%
df["PHYSHLTH"].describe()
# Out:
# count    34545.000000
# mean        60.213403
# std         37.504566
# min          1.000000
# 25%         15.000000
# 50%         88.000000
# 75%         88.000000
# max         99.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 1. Handle the non-normal values
#
# As you can see from the data dictionary, there are a number of responses that are coded with values that could throw off our descriptive statistics.  Let's clean up by mapping the responses to a more appropriate value, and handling any missing values.

# %%
#your code here
# CREATE DICTIONARY WITH VVALUE MAPPINGS
#USE DICTIONARY WITH REPLACE METHOD TO DEAL WITHNON NORMAL VALUES

# %%
code_replace = {88:0,
                 77:np.nan,
                 99:np.nan}

# %%
df['PHYSHLTH'].replace(code_replace, inplace= True)

# %%
df.PHYSHLTH.describe()
# Out:
# count    33747.000000
# mean         4.085341
# std          8.513293
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max         30.000000
# Name: PHYSHLTH, dtype: float64

# %% [markdown]
# ## 2. Generate the descriptive statistics
#
# Now that our target variable is cleaned up lets calculate the descriptive statistics, generate a graph that quickly shows those statistics, and generate a gprah shows the histogram of the data.

# %%
PHYSICAL = df["PHYSHLTH"]
PHYSICAL.head(20)
# Out:
# 49938     0.0
# 49939     0.0
# 49940     2.0
# 49941     0.0
# 49942     0.0
# 49943     0.0
# 49944     0.0
# 49945     0.0
# 49946    28.0
# 49947     0.0
# 49948     0.0
# 49949     0.0
# 49950     5.0
# 49951     0.0
# 49952     2.0
# 49953     2.0
# 49954     0.0
# 49955    30.0
# 49956     0.0
# 49957     0.0
# Name: PHYSHLTH, dtype: float64

# %%
# descriptive statistics
df['PHYSHLTH'].describe()
# Out:
# count    33747.000000
# mean         4.085341
# std          8.513293
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          3.000000
# max         30.000000
# Name: PHYSHLTH, dtype: float64

# %%
df

# %%
# graphic showing those descriptive stats
# #Plot the histogram with hist() function

plt.title("Days missed over previous month")
plt.hist(df["PHYSHLTH"], bins = 10, edgecolor = "black" )
plt.xlabel(df["Physical Health"])
plt.ylabel("Frequency of Values")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
# graphic showing the distribution of data

# %% [markdown]
# ## 3. Generate a graphic that compares the average number of sick days for each state.

# %%
df.head()
# Out:
#         Unnamed: 0  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE  \
# _STATE
# 9.0          49938     5.0  5172017       5    17   2017    1200.0
# 9.0          49939     2.0  2142017       2    14   2017    1200.0
# 9.0          49940     1.0  1292017       1    29   2017    1200.0
# 9.0          49941     7.0  9112017       9    11   2017    1200.0
# 9.0          49942     5.0  7182017       7    18   2017    1200.0
#
#              SEQNO          _PSU  CTELENM1  ...  _PA300R2  _PA30021  _PASTRNG  \
# _STATE                                      ...
# 9.0     2017000001  2.017000e+09       NaN  ...       2.0       2.0       2.0
# 9.0     2017000002  2.017000e+09       NaN  ...       1.0       1.0       1.0
# 9.0     2017000003  2.017000e+09       NaN  ...       3.0       2.0       1.0
# 9.0     2017000004  2.017000e+09       NaN  ...       2.0       2.0       2.0
# 9.0     2017000005  2.017000e+09       NaN  ...       2.0       2.0       1.0
#
# ...

# %%
# code to calculate the average number of sick days by state
df._STATE.unique()
# Out:
# array([ 9., 34., 36.])

# %%
df.groupby("_STATE")["PHYSHLTH"].mean()
# Out:
# _STATE
# 9.0     3.688562
# 34.0    4.380957
# 36.0    4.148030
# Name: PHYSHLTH, dtype: float64

# %%
tri_state_mean = df.groupby("_STATE")["PHYSHLTH"].mean().values
tri_state_mean
states = ["Conn", "NJ", "NY"]

# %%
# code to graph those averages using matplotlib
plt.figure(figsize=(6, 6))
plt.axes()
plt.title("Comparing average sick days for Conn, NJ & NY")
plt.xlabel("States")
plt.ylabel("Average monthly sick days")
plt.bar(states, tri_state_mean)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## 4. Turn the number of sick days into a classification of of chronically sick people.
#
# Chronically sick people account for a significant proportion of the costs for health insurers. If we can identify what leads people to be chronically sick, we can address them with specific treatments.

# %%
# code to create new colum for chronically sick     np.where  df['CHRONIC'] = np.where(df['PHYSHLTH']>=20, 1,0)
df["Chronically Ill"] = np.where(df["PHYSHLTH"] > 7, 1, 0)
df.head(10)
# Out:
#        _STATE  FMONTH    IDATE  IMONTH  IDAY  IYEAR  DISPCODE       SEQNO  \
# 49938     9.0     5.0  5172017       5    17   2017    1200.0  2017000001
# 49939     9.0     2.0  2142017       2    14   2017    1200.0  2017000002
# 49940     9.0     1.0  1292017       1    29   2017    1200.0  2017000003
# 49941     9.0     7.0  9112017       9    11   2017    1200.0  2017000004
# 49942     9.0     5.0  7182017       7    18   2017    1200.0  2017000005
# 49943     9.0     1.0  1192017       1    19   2017    1100.0  2017000006
# 49944     9.0     1.0  2032017       2     3   2017    1100.0  2017000007
# 49945     9.0     1.0  2012017       2     1   2017    1100.0  2017000008
# 49946     9.0     1.0  1262017       1    26   2017    1100.0  2017000009
# 49947     9.0     1.0  1192017       1    19   2017    1100.0  2017000010
#
#                _PSU  CTELENM1  ...  _PA30021  _PASTRNG  _PAREC1  _PASTAE1  \
# 49938  2.017000e+09       NaN  ...       2.0       2.0      4.0       2.0
# ...

# %% [markdown]
# ## 5. Create a graphic that compares the percentage of people labeled as 'sick' in each state.

# %%
# code to calculate averages per state
avg_ill = df.groupby("_STATE")["Chronically Ill"].mean()
avg_ill
# Out:
# _STATE
# 9.0     0.136097
# 34.0    0.161855
# 36.0    0.151441
# Name: Chronically Ill, dtype: float64

# %%
# create graphic to compare chronically sick by state
plt.figure(figsize=(6,6))
plt.title("Chronically ill by state")
plt.bar("_STATE", "avg_ill")
# Out:
# <BarContainer object of 1 artists>

# %% [markdown]
# ## 6. Independent Variables (categorical)
#
# Let's take the column `SMOKDAY2` and start to prepare it so that we can see how it is possibly correlated to `PHYSHLTH`.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Generate a graphic that compares the physical health of the different groups of 'smokers'.

# %%
# 7. Write a Pandas program to select the rows where 
#the number of attempts in the examination is 
#greater than 2. Go to the editor
# Sample Python dictionary data and list labels:
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# Expected Output:
# Number of attempts in the examination is greater than 2:
# name score attempts qualify
# b Dima 9.0 3 no
# d James NaN 3 no
# f Michael 20.0 3 yes
df = pd.DataFrame(exam_data, index= labels)


#df.groupby('name')['attempts'].describe()
df[df["attempts"] > 2]
# Out:
#       name  score  attempts qualify
# b     Dima    9.0         3      no
# d    James    NaN         3      no
# f  Michael   20.0         3     yes

# %% [markdown]
# ## 7. Independent Variables (continuous):
#
# Now let's look at a continuous variable (ALCDAY5) and see how that might impact a person's health.
#
# 1. Clean up the values.
# 2. Calculate the descriptive statistics of the variable.
# 3. Generate a histogram for the variable.
# 4. Generate graphics that show how the responses to this variable might differ by state.
# 5. Calculate the correlation coefficient between `PHYSHLTH` and `ALCDAY5`.
# 5. Generate a graphic that shows the possible relationship between `PHYSHLTH` and `ALCDAY5`.

# %% [markdown]
# ## 8. Additional variables: Choose two additional survey items you would like to investigate do steps  6 or 7 for those variables.

# %%
# your code here

# %% [markdown]
# ## 9. Based on your initial data exploration, what are some hypotheses of what affects a person's health that you would like to further investigate?

# %% [markdown]
# Type out your initial hyptotheses below:
#
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ## Bonus: Create some cool graphics.
